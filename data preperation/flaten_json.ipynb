# %%
import os
import json

base_dir = os.path.dirname(__file__)
file_path = os.path.join(base_dir, "data/procedures/osha_confined_spaces_faq.json")

with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 import os
#       2 import json
# ----> 4 base_dir = os.path.dirname(__file__)
#       5 file_path = os.path.join(base_dir, "data/procedures/osha_confined_spaces_faq.json")
#       7 with open(file_path, "r", encoding="utf-8") as f:
#
# NameError: name '__file__' is not defined
